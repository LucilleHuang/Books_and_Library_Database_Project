# %%
import pandas as pd
import glob

path = r'C:/Users/lucil/Documents/_Changed/TrackWithGit/ECE356_Books_and_Library_Database_Project/Data/Library' # use your path
all_files = glob.glob(path + "/Checkouts*.csv")

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

checkouts = pd.concat(li, axis=0, ignore_index=True)
checkouts
# Out:
# C:\Users\lucil\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           BibNumber  ItemBarcode ItemType Collection               CallNumber  \
# 0           1842225  10035249209     acbk      namys       MYSTERY ELKINS1999
# 1           1928264  10037335444     jcbk      ncpic                 E TABACK
# 2           1982511  10039952527    jcvhs    ncvidnf  VHS J796.2 KNOW_YO 2000
# 3           2026467  10040985615     accd       nacd       CD 782.421642 Y71T
# 4           2174698  10047696215     jcbk      ncpic                E KROSOCZ
# ...             ...          ...      ...        ...                      ...
# 91980688    2661830  10068153815     accd       nacd       CD 782.42166 L6973
# 91980689    3208256  10088796528     jcbk    cccomic     J741.5993 On28P 2016
# ...

# %%
boolean = checkouts.duplicated().any()
boolean
# Out:
# True

# %%
checkoutOfBook = checkouts.loc[(checkouts['BibNumber'] == 3208256),('BibNumber','ItemBarcode')]
checkoutOfBook
checkoutOfBook.drop_duplicates()
# Out:
#           BibNumber  ItemBarcode
# 80887555    3208256  10088796536
# 81341132    3208256  10088796593
# 81709766    3208256  10088796486
# 81991209    3208256  10088796577
# 82001725    3208256  10088796494
# 82469582    3208256  10088796569
# 82540597    3208256  10088796544
# 82898129    3208256  10088796585
# 83186505    3208256  10088796528
# 84062370    3208256  10088796502
# 84104636    3208256  10088796551
# 85418997    3208256  10088796510

# %%
import pandas as pd
path = r'C:/Users/lucil/Documents/_Changed/TrackWithGit/ECE356_Books_and_Library_Database_Project/Data/Library/Library_Collection_Inventory.csv'
collection = pd.read_csv(path, index_col=None, header=0)
collection
# Out:
#           BibNum                                              Title  \
# 0        3011076  A tale of two friends / adapted by Ellie O'Rya...
# 1        2248846  Naruto. Vol. 1, Uzumaki Naruto / story and art...
# 2        3209270  Peace, love & Wi-Fi : a ZITS treasury / by Jer...
# 3        1907265     The Paris pilgrims : a novel / Clancy Carlile.
# 4        1644616  Erotic by nature : a celebration of life, of l...
# ...          ...                                                ...
# 2687144  2744361     The hunter [sound recording] / John Lescroart.
# 2687145  3161311  The black moon : a novel of Cornwall, 1794-179...
# 2687146  2932295  Ukraine / Andrew Evans ; updated by Massimilia...
# 2687147  1253883  Why the Confederacy lost / edited by Gabor S. ...
# 2687148   448178  Selected songs of the masters [music] : a coll...
#
#                             Author  \
# 0                    O'Ryan, Ellie
# 1        Kishimoto, Masashi, 1974-
# 2              Scott, Jerry, 1955-
# ...

# %%
dup = collection.duplicated(subset=['BibNum','ItemType','ItemCollection','ItemLocation','ReportDate'])
collection.loc[dup]
# Out:
# Empty DataFrame
# Columns: [BibNum, Title, Author, ISBN, PublicationYear, Publisher, Subjects, ItemType, ItemCollection, FloatingItem, ItemLocation, ReportDate, ItemCount]
# Index: []

# %%
# contain_values = collection.loc[(',' in collection['PublicationYear'])]
contain_values = collection.dropna()
contain_values = contain_values[contain_values['PublicationYear'].str.contains(r',.+,.+')]
contain_values
# Out:
#           BibNum                                              Title  \
# 96781    2546726  Murder in Mesopotamia [sound recording] / by A...
# 231574   2611548  The hitchhiker's guide to the galaxy. Primary ...
# 271037   3178426   Monk's hood [sound recording] / by Ellis Peters.
# 531210   3046214  The unpleasantness at the Bellona Club : a Lor...
# 781532   2611488  The hitchhiker's guide to the galaxy. Secondar...
# 852726   2841590  Magnificence [sound recording] : [a novel] / L...
# 1036894  3029062  Crown of midnight [sound recording] / Sarah J....
# 1073399  2546726  Murder in Mesopotamia [sound recording] / by A...
# 1091021  2588572  Little Dorrit [sound recording] / Charles Dick...
# 1248621  3046214  The unpleasantness at the Bellona Club : a Lor...
# 1409639  3178426   Monk's hood [sound recording] / by Ellis Peters.
# 1448794  2588572  Little Dorrit [sound recording] / Charles Dick...
# 1476340  2611488  The hitchhiker's guide to the galaxy. Secondar...
# ...

# %%
collection['ReportDate'].max()
# Out:
# '10/01/2017'

# %%
collection['ReportDate'].min()
# Out:
# '09/01/2017'

# %%
contain_values.loc[131]['Publisher']
# Out:
# 'Thorndike Press, a part of Gale, Cengage Learning,'

# %%
book = collection.loc[(collection['BibNum'] == 3208256) ]#& (collection['ItemType'] =='arbk') & (collection['ItemCollection']=='cs6r') #& (collection['ItemLocation']=='cen')]
book.drop_duplicates()
# Out:
#           BibNum                                              Title  \
# 130407   3208256  Princess Princess ever after / by Katie O'Neil...
# 156504   3208256  Princess Princess ever after / by Katie O'Neil...
# 255005   3208256  Princess Princess ever after / by Katie O'Neil...
# 395769   3208256  Princess Princess ever after / by Katie O'Neil...
# 729837   3208256  Princess Princess ever after / by Katie O'Neil...
# 806856   3208256  Princess Princess ever after / by Katie O'Neil...
# 1131954  3208256  Princess Princess ever after / by Katie O'Neil...
# 1138989  3208256  Princess Princess ever after / by Katie O'Neil...
# 1175997  3208256  Princess Princess ever after / by Katie O'Neil...
# 1176838  3208256  Princess Princess ever after / by Katie O'Neil...
# 1215198  3208256  Princess Princess ever after / by Katie O'Neil...
# 1544997  3208256  Princess Princess ever after / by Katie O'Neil...
# 1672490  3208256  Princess Princess ever after / by Katie O'Neil...
# ...

# %%
import pandas as pd
path = r'C:/Users/lucil/Documents/_Changed/TrackWithGit/ECE356_Books_and_Library_Database_Project/Data/Library/Integrated_Library_System__ILS__Data_Dictionary.csv'
data_dict = pd.read_csv(path, index_col=None, header=0)
data_dict
# Out:
#        Code                       Description     Code Type Format Group  \
# 0    pkbknh                   Peak Picks Book      ItemType          NaN
# 1     acart              Framed Art: Adult/YA      ItemType        Media
# 2      acbk                    Book: Adult/YA      ItemType        Print
# 3     accas              Audio Tape: Adult/YA      ItemType        Media
# 4      accd                      CD: Adult/YA      ItemType        Media
# ..      ...                               ...           ...          ...
# 550     spa         South Park, 8604 8TH AV S  ItemLocation          NaN
# 551     swt        Southwest, 9010 35TH AV SW  ItemLocation          NaN
# 552     uni  University, 5009 ROOSEVELT WY NE  ItemLocation          NaN
# 553     wal       Wallingford, 1501 N 45TH ST  ItemLocation          NaN
# 554     wts     West Seattle, 2306 42ND AV SW  ItemLocation          NaN
#
#     Format Subgroup Category Group Category Subgroup
# ...

# %%
max(data_dict['Description'].apply(len))
# Out:
# 46
